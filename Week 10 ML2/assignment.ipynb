# %% [markdown]
# # Homework
#
# Fill your code where `# TODO` is placed.

# %%
import pickle

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import matplotlib.pyplot as plt

from itertools import product

# %matplotlib inline

# %% [markdown]
# ## Read Dataset
#
# - Data Description
#   - trainset = (X_train, y_train)
#     - X_train.shape = (2500, 2)
#     - y_train.shape = (2500, 1)
#   - testset = (X_test, y_test)
#     - X_test.shape = (500, 2)
#     - y_test.shape = (500, 1)
#
# - What to do?
#   - train a neural network which classify two class.
#
#
# - **HINT** : These functions might help you. (Although it's your job to find out how to properly use these!)
#   - ```torch.softmax```
#   - ```X.unsqueeze(0)```
#   - ```X.item()```

# %%
with open('train.pkl', 'rb') as f:
    trainset = pickle.load(f)
    
with open('test.pkl', 'rb') as f:
    testset = pickle.load(f)
    
trainset = list(zip(trainset[0], trainset[1]))
testset = list(zip(testset[0], testset[1]))

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # two input fields, one output field and two layers in between
        self.fc1 = nn.Linear(2, 20)
        self.fc2 = nn.Linear(20, 10)
        self.fc3 = nn.Linear(10, 2)

        
    def forward(self, x):
        x = torch.tensor(x)
        #x = torch.softmax(self.fc1(x), dim=0) # thats how it works with softmax (you recommended them above but relu works better here in my tests
        #x = torch.softmax(self.fc2(x), dim=0)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))

        x = self.fc3(x)
        sigm = nn.Sigmoid()
        x = sigm(x)
        return x

# %% [markdown]
# ## Train

# %%
model = Net()
model = model.double()
optimizer = optim.SGD(model.parameters(), lr=0.1)
criterion = nn.CrossEntropyLoss()  ## Be careful! This function takes very specific forms of inputs.

# %%
def train(model, trainset, optimizer, criterion):
    train_loss = []
    for x, y in trainset:
        pred_y = model(x)

        loss = criterion(pred_y.unsqueeze(0).float(), torch.tensor([y]))
        model.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss.append(loss.item())

    return train_loss

# %%
losses = []
for i in range(3):
    loss = train(model, trainset, optimizer, criterion)
    print(f'Training run {i+1}, loss = {np.average(loss)}')
    losses.append(np.average(loss))
# Out:
# Training run 1, loss = 0.3988715882062912
# Training run 2, loss = 0.31803152097463605
# Training run 3, loss = 0.31457123950719834

# %%
steps = np.arange(1,len(losses)+1)
losses = np.array(losses)
plt.scatter(steps, losses, marker='+')

# %% [markdown]
# ## Test

# %%
def test(model, testset, criterion):  # we don't need optimizer here!
    test_loss = 0.
    losses = []
    for x, y in testset:
        pred_y = model(x)

        loss = criterion(pred_y.unsqueeze(0).float(), torch.tensor([y]))

        losses.append(loss.item())
    test_loss = np.average(losses)
    return test_loss

# %%
test(model, testset, criterion)
# Out:
# 0.3142708460688591

# %% [markdown]
# ## Full pipeline
# - Stop the iteration when the test loss reaches below ```0.32```.

# %%
model = Net()
model = model.double()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 200
losses = []
for epoch in range(epochs):
    loss = train(model, trainset, optimizer, criterion)
    print(f'Training run {epoch}, loss = {np.average(loss)}')
    losses.append(np.average(loss))
    if losses[-1] < .32:
        break
# Out:
# Training run 0, loss = 0.5968748255372047
# Training run 1, loss = 0.4421682837367058
# Training run 2, loss = 0.41694290385246274
# Training run 3, loss = 0.40588661487102506
# Training run 4, loss = 0.39607673197984694
# Training run 5, loss = 0.38593825711011887
# Training run 6, loss = 0.3742144325017929
# Training run 7, loss = 0.35991466031074526
# Training run 8, loss = 0.34397634690999984
# Training run 9, loss = 0.3322398793935776
# Training run 10, loss = 0.32578694595098495
# Training run 11, loss = 0.32219157291650774
# Training run 12, loss = 0.32002411373853684
# Training run 13, loss = 0.31860528671741484

# %%
steps = np.arange(1,len(losses)+1)
losses = np.array(losses)
plt.scatter(steps, losses, marker='+')

# %% [markdown]
# ## Visualize your neural network outputs
#
# - Pass the `viz_X` tensor to the networks and visualize the outputs with matplotlib

# %%
viz_X = np.array(list(product(np.linspace(-1.3, 2.3, 50, dtype=np.float32), 
                              np.linspace(-0.8, 1.3, 50, dtype=np.float32))))

# %%
# get result, make it a vector (it was hot vector encoded) and make it a numpy array
y = model(torch.tensor(viz_X).double())
y = y[:,0] - y[:,1]
y = y.detach().numpy()

plt.figure(figsize=(6, 5))
plt.scatter(viz_X[:,0], viz_X[:, 1], c=y, s=10, cmap='bwr')
plt.colorbar()
# Out:
# /tmp/ipykernel_25935/2703386524.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)

# %% [markdown]
# ## Save Model

# %%
torch.save(model.state_dict(), 'model.pth')

# %% [markdown]
# ## Load Model

# %%
state_dict = torch.load('model.pth')
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
state_dict
# Out:
# OrderedDict([('fc1.weight',
#               tensor([[-0.1215, -0.6223],
#                       [-0.8291,  0.5460],
#                       [-0.3997,  0.1678],
#                       [ 0.4511,  0.7038],
#                       [ 2.0929,  0.6278],
#                       [ 0.7773,  0.0324],
#                       [ 0.0712,  0.3832],
#                       [ 0.2862,  0.1998],
#                       [ 0.4389, -0.2277],
#                       [-1.3490, -0.0594],
#                       [ 1.1447,  0.4081],
#                       [-0.6045, -0.3520],
#                       [ 1.1197, -0.5037],
#                       [ 0.0925, -0.7752],
#                       [ 0.9155, -0.9219],
#                       [-0.2702,  0.8506],
#                       [ 1.3489,  0.3790],
#                       [-0.4097,  0.5686],
#                       [ 0.0216, -0.2602],
#                       [-0.8816,  0.0505]], dtype=torch.float64)),
#              ('fc1.bias',
#               tensor([ 0.7778, -0.2091,  0.7681, -0.1272, -0.2337,  0.8831,  0.3456, -0.7029,
#                        0.5643,  0.0504, -1.1678, -0.5135, -1.0855,  0.9603, -0.8546,  0.6116,
#                       -1.3733,  0.7559,  0.3267, -0.0054], dtype=torch.float64)),
#              ('fc2.weight',
#               tensor([[ 0.3879, -0.2323,  0.1839, -0.1521, -1.0498,  0.5171,  0.1205, -0.0733,
#                         0.4372, -0.4974,  0.9110, -0.0569,  1.0163,  0.5938,  0.9760, -0.2393,
#                         1.0120,  0.1091,  0.1831, -0.5578],
#                       [ 0.1159,  0.0562,  0.1858, -0.1279, -0.1208,  0.1661, -0.0373, -0.2082,
#                         0.0068,  0.0993,  0.0206, -0.0897,  0.1945,  0.1467, -0.0899, -0.1096,
#                         0.3597, -0.0321,  0.0868,  0.0183],
#                       [ 0.3397, -0.1556,  0.1136, -0.2750, -0.7774,  0.3456, -0.1812,  0.2050,
#                         0.3891, -0.6337,  0.5908, -0.0499,  0.5394,  0.4811,  0.6497,  0.0285,
#                         0.6799,  0.1024,  0.2164, -0.4313],
#                       [ 0.1737,  0.1993, -0.0901,  0.0526,  0.2196, -0.2015, -0.1328, -0.2190,
#                         0.1236,  0.1180,  0.2281,  0.1220,  0.2115, -0.1713, -0.1221, -0.0976,
#                        -0.1569, -0.2018, -0.1432, -0.2093],
#                       [-0.0841, -0.1313, -0.1239, -0.0083, -0.0718, -0.0957, -0.0264, -0.1850,
#                         0.1879,  0.0887, -0.1700,  0.0069,  0.0926, -0.2350, -0.0528,  0.1270,
#                         0.1672,  0.0027,  0.0056,  0.1764],
#                       [-0.0872,  0.1726, -0.2090, -0.0595,  0.0418,  0.2017, -0.2365, -0.0113,
#                         0.2199,  0.0882,  0.3278,  0.0456,  0.0385, -0.0786,  0.3681, -0.1309,
#                         0.3202, -0.3192,  0.0610,  0.2073],
#                       [ 0.0916,  0.0966, -0.1313, -0.0044,  0.0695,  0.0993, -0.1289, -0.0919,
#                         0.0504, -0.1020, -0.1138, -0.2188,  0.1000,  0.2035,  0.1460,  0.1149,
#                         0.2198,  0.0055, -0.0287, -0.1925],
#                       [-0.3102,  0.2373, -0.0201,  0.2863,  0.3613,  0.1184, -0.0456, -0.0540,
#                        -0.1038,  0.1840, -0.2082,  0.1084, -0.3737, -0.1400, -0.1090,  0.3655,
#                        -0.3623,  0.2733,  0.0317,  0.3290],
#                       [-0.3829,  0.6637,  0.2829,  0.2659,  1.4301, -0.0455,  0.3339,  0.1567,
#                        -0.0790,  0.8186, -1.0881, -0.1176, -0.8628, -0.5588, -0.4729,  0.5561,
#                        -1.2641,  0.4373, -0.1918,  0.3449],
#                       [-0.1948,  0.0618, -0.2427,  0.1870,  0.2342,  0.0198, -0.0787, -0.0794,
#                         0.1308, -0.0625,  0.0277,  0.0355,  0.3302, -0.0278,  0.1437, -0.2126,
#                         0.0936, -0.1722,  0.1252, -0.1826]], dtype=torch.float64)),
#              ('fc2.bias',
#               tensor([ 0.5530,  0.1021,  0.4162,  0.1057, -0.0280, -0.1566,  0.0965,  0.0746,
#                        0.2528, -0.2820], dtype=torch.float64)),
#              ('fc3.weight',
#               tensor([[-1.7798, -0.3143, -1.1783, -0.1240, -0.2011, -0.3949, -0.3396,  0.6424,
#                         2.0840, -0.3670],
#                       [ 1.8536,  0.1762,  1.3902,  0.3389,  0.1634,  0.5601, -0.0233, -0.6788,
#                        -1.9082,  0.3532]], dtype=torch.float64)),
#              ('fc3.bias', tensor([-0.2254, -0.2265], dtype=torch.float64))])
